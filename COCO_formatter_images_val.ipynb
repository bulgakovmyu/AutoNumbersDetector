# %%
import json
import os

# %%
annot_path_real = 'data\\real_val_autonumber_annotations.json'
annot_path_syn = 'data\\syn_val_autonumber_annotations.json'

# %%
with open(annot_path_syn) as f:
    annotation_list_syn = json.load(f)
with open(annot_path_real) as f:
    annotation_list_real = json.load(f)

# %%
annotation_list_syn
# Out:
# [{'annotation': [{'class': 'rect',
#     'width': 98,
#     'height': 82,
#     'x': 718.0,
#     'y': 574.0,
#     'number': 'T127KA10'},
#    {'class': 'rect',
#     'width': 65,
#     'height': 57,
#     'x': 861.5,
#     'y': 177.5,
#     'number': 'P058CH125'},
#    {'class': 'rect',
#     'width': 72,
#     'height': 66,
#     'x': 673.0,
#     'y': 578.0,
#     'number': 'X492OP27'},
#    {'class': 'rect',
#     'width': 103,
#     'height': 74,
#     'x': 761.5,
#     'y': 112.0,
#     'number': 'H490PA197'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_0.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 90,
#     'height': 42,
#     'x': 204.0,
#     'y': 575.0,
#     'number': 'E676HM79'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_1.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 69,
#     'height': 59,
#     'x': 387.5,
#     'y': 612.5,
#     'number': 'B856OM78'},
#    {'class': 'rect',
#     'width': 70,
#     'height': 59,
#     'x': 244.0,
#     'y': 112.5,
#     'number': 'O677HB10'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_2.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 55,
#     'height': 36,
#     'x': 850.5,
#     'y': 407.0,
#     'number': 'B503AC65'},
#    {'class': 'rect',
#     'width': 69,
#     'height': 46,
#     'x': 707.5,
#     'y': 326.0,
#     'number': 'A864PK38'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_3.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 79,
#     'height': 31,
#     'x': 722.5,
#     'y': 345.5,
#     'number': 'P878OC121'},
#    {'class': 'rect',
#     'width': 75,
#     'height': 45,
#     'x': 601.5,
#     'y': 206.5,
#     'number': 'K756OX95'},
#    {'class': 'rect',
#     'width': 83,
#     'height': 52,
#     'x': 271.5,
#     'y': 618.0,
#     'number': 'A199EA50'},
#    {'class': 'rect',
#     'width': 88,
#     'height': 60,
#     'x': 608.0,
#     'y': 190.0,
#     'number': 'E329HM48'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_4.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 82,
#     'height': 69,
#     'x': 861.0,
#     'y': 605.5,
#     'number': 'K147TY12'},
#    {'class': 'rect',
#     'width': 75,
#     'height': 57,
#     'x': 829.5,
#     'y': 396.5,
#     'number': 'T056OB46'},
#    {'class': 'rect',
#     'width': 71,
#     'height': 28,
#     'x': 299.5,
#     'y': 428.0,
#     'number': 'Y896KB43'},
#    {'class': 'rect',
#     'width': 107,
#     'height': 65,
#     'x': 335.5,
#     'y': 523.5,
#     'number': 'H653AX84'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_5.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 71,
#     'height': 58,
#     'x': 813.5,
#     'y': 316.0,
#     'number': 'E740XC33'},
#    {'class': 'rect',
#     'width': 73,
#     'height': 72,
#     'x': 509.5,
#     'y': 407.0,
#     'number': 'O304XB65'},
#    {'class': 'rect',
#     'width': 93,
#     'height': 56,
#     'x': 931.5,
#     'y': 110.0,
#     'number': 'B657OK154'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_6.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 99,
#     'height': 29,
#     'x': 417.5,
#     'y': 281.5,
#     'number': 'A325CB16'},
#    {'class': 'rect',
#     'width': 92,
#     'height': 74,
#     'x': 189.0,
#     'y': 370.0,
#     'number': 'B130AB98'},
#    {'class': 'rect',
#     'width': 86,
#     'height': 60,
#     'x': 198.0,
#     'y': 175.0,
#     'number': 'T708AT88'},
#    {'class': 'rect',
#     'width': 75,
#     'height': 45,
#     'x': 607.5,
#     'y': 127.5,
#     'number': 'A108KY138'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_7.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 82,
#     'height': 55,
#     'x': 948.0,
#     'y': 411.5,
#     'number': 'O912OT39'},
#    {'class': 'rect',
#     'width': 98,
#     'height': 71,
#     'x': 836.0,
#     'y': 265.5,
#     'number': 'K228KP26'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_8.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 88,
#     'height': 72,
#     'x': 708.0,
#     'y': 525.0,
#     'number': 'O707YP57'},
#    {'class': 'rect',
#     'width': 78,
#     'height': 49,
#     'x': 147.0,
#     'y': 250.5,
#     'number': 'M061PX190'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_9.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 67,
#     'height': 51,
#     'x': 444.5,
#     'y': 488.5,
#     'number': 'K094YP75'},
#    {'class': 'rect',
#     'width': 94,
#     'height': 78,
#     'x': 706.0,
#     'y': 337.0,
#     'number': 'T501BB61'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_10.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 90,
#     'height': 33,
#     'x': 894.0,
#     'y': 450.5,
#     'number': 'A979HY43'},
#    {'class': 'rect',
#     'width': 71,
#     'height': 67,
#     'x': 439.5,
#     'y': 642.5,
#     'number': 'A614EY82'},
#    {'class': 'rect',
#     'width': 102,
#     'height': 85,
#     'x': 872.0,
#     'y': 436.5,
#     'number': 'Y614AC169'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_11.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 59,
#     'height': 37,
#     'x': 253.5,
#     'y': 304.5,
#     'number': 'M403KX77'},
#    {'class': 'rect',
#     'width': 69,
#     'height': 41,
#     'x': 858.5,
#     'y': 344.5,
#     'number': 'C335YX68'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_12.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 67,
#     'height': 58,
#     'x': 680.5,
#     'y': 300.0,
#     'number': 'K017EM49'},
#    {'class': 'rect',
#     'width': 96,
#     'height': 31,
#     'x': 466.0,
#     'y': 185.5,
#     'number': 'T643YC22'},
#    {'class': 'rect',
#     'width': 63,
#     'height': 43,
#     'x': 747.5,
#     'y': 448.5,
#     'number': 'M124PA21'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_13.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 70,
#     'height': 54,
#     'x': 329.0,
#     'y': 293.0,
#     'number': 'E344AA53'},
#    {'class': 'rect',
#     'width': 90,
#     'height': 65,
#     'x': 221.0,
#     'y': 233.5,
#     'number': 'T582BC197'},
#    {'class': 'rect',
#     'width': 97,
#     'height': 45,
#     'x': 394.5,
#     'y': 434.5,
#     'number': 'M541PB58'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_14.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 92,
#     'height': 64,
#     'x': 935.0,
#     'y': 206.0,
#     'number': 'H841EB57'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_15.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 102,
#     'height': 53,
#     'x': 994.0,
#     'y': 279.5,
#     'number': 'C652HO41'},
#    {'class': 'rect',
#     'width': 55,
#     'height': 33,
#     'x': 677.5,
#     'y': 198.5,
#     'number': 'K837AP13'},
#    {'class': 'rect',
#     'width': 89,
#     'height': 32,
#     'x': 441.5,
#     'y': 304.0,
#     'number': 'A885EC67'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_16.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 87,
#     'height': 57,
#     'x': 389.5,
#     'y': 125.5,
#     'number': 'K246HP79'},
#    {'class': 'rect',
#     'width': 74,
#     'height': 70,
#     'x': 472.0,
#     'y': 182.0,
#     'number': 'Y500BY71'},
#    {'class': 'rect',
#     'width': 59,
#     'height': 40,
#     'x': 604.5,
#     'y': 259.0,
#     'number': 'C984TA4'},
#    {'class': 'rect',
#     'width': 62,
#     'height': 39,
#     'x': 254.0,
#     'y': 269.5,
#     'number': 'H637PE8'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_17.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 87,
#     'height': 75,
#     'x': 731.5,
#     'y': 623.5,
#     'number': 'O054PM1'},
#    {'class': 'rect',
#     'width': 87,
#     'height': 57,
#     'x': 364.5,
#     'y': 327.5,
#     'number': 'B337CH77'},
#    {'class': 'rect',
#     'width': 89,
#     'height': 37,
#     'x': 863.5,
#     'y': 377.5,
#     'number': 'B437PK43'},
#    {'class': 'rect',
#     'width': 69,
#     'height': 51,
#     'x': 888.5,
#     'y': 248.5,
#     'number': 'K986TK62'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_18.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 91,
#     'height': 55,
#     'x': 605.5,
#     'y': 67.5,
#     'number': 'A983YC77'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_19.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 98,
#     'height': 55,
#     'x': 317.0,
#     'y': 449.5,
#     'number': 'Y971BK83'},
#    {'class': 'rect',
#     'width': 55,
#     'height': 51,
#     'x': 350.5,
#     'y': 108.5,
#     'number': 'E480KO197'},
#    {'class': 'rect',
#     'width': 105,
#     'height': 63,
#     'x': 644.5,
#     'y': 490.5,
#     'number': 'M470TB68'},
#    {'class': 'rect',
#     'width': 77,
#     'height': 47,
#     'x': 426.5,
#     'y': 429.5,
#     'number': 'C656EB72'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_20.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 76,
#     'height': 63,
#     'x': 428.0,
#     'y': 207.5,
#     'number': 'Y054YY16'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_21.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 60,
#     'height': 35,
#     'x': 832.0,
#     'y': 321.5,
#     'number': 'M631OC11'},
#    {'class': 'rect',
#     'width': 81,
#     'height': 63,
#     'x': 349.5,
#     'y': 203.5,
#     'number': 'A854YT15'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_22.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 56,
#     'height': 44,
#     'x': 502.0,
#     'y': 308.0,
#     'number': 'Y544CX23'},
#    {'class': 'rect',
#     'width': 86,
#     'height': 76,
#     'x': 410.0,
#     'y': 456.0,
#     'number': 'X817EP29'},
#    {'class': 'rect',
#     'width': 78,
#     'height': 64,
#     'x': 650.0,
#     'y': 329.0,
#     'number': 'Y919XH22'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_23.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 63,
#     'height': 36,
#     'x': 247.5,
#     'y': 453.0,
#     'number': 'P450AM8'},
#    {'class': 'rect',
#     'width': 88,
#     'height': 35,
#     'x': 493.0,
#     'y': 172.5,
#     'number': 'E254CM190'},
#    {'class': 'rect',
#     'width': 65,
#     'height': 37,
#     'x': 852.5,
#     'y': 292.5,
#     'number': 'P620EO777'},
#    {'class': 'rect',
#     'width': 64,
#     'height': 61,
#     'x': 780.0,
#     'y': 411.5,
#     'number': 'C660BC89'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_24.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 57,
#     'height': 39,
#     'x': 715.5,
#     'y': 383.5,
#     'number': 'M895CE45'},
#    {'class': 'rect',
#     'width': 92,
#     'height': 79,
#     'x': 549.0,
#     'y': 102.5,
#     'number': 'K517EB64'},
#    {'class': 'rect',
#     'width': 100,
#     'height': 53,
#     'x': 427.0,
#     'y': 502.5,
#     'number': 'Y926ME197'},
#    {'class': 'rect',
#     'width': 73,
#     'height': 56,
#     'x': 635.5,
#     'y': 164.0,
#     'number': 'M831MX31'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_25.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 63,
#     'height': 57,
#     'x': 514.5,
#     'y': 444.5,
#     'number': 'T938YB97'},
#    {'class': 'rect',
#     'width': 71,
#     'height': 58,
#     'x': 604.5,
#     'y': 364.0,
#     'number': 'C901MA86'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_26.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 88,
#     'height': 57,
#     'x': 797.0,
#     'y': 160.5,
#     'number': 'C683HO8'},
#    {'class': 'rect',
#     'width': 63,
#     'height': 55,
#     'x': 566.5,
#     'y': 467.5,
#     'number': 'A743MH2'},
#    {'class': 'rect',
#     'width': 95,
#     'height': 38,
#     'x': 862.5,
#     'y': 581.0,
#     'number': 'B366PP89'},
#    {'class': 'rect',
#     'width': 104,
#     'height': 81,
#     'x': 285.0,
#     'y': 105.5,
#     'number': 'A927TC74'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_27.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 92,
#     'height': 63,
#     'x': 260.0,
#     'y': 573.5,
#     'number': 'Y686AX19'},
#    {'class': 'rect',
#     'width': 75,
#     'height': 43,
#     'x': 225.5,
#     'y': 560.5,
#     'number': 'M158PM72'},
#    {'class': 'rect',
#     'width': 98,
#     'height': 73,
#     'x': 604.0,
#     'y': 195.5,
#     'number': 'X031PB197'},
#    {'class': 'rect',
#     'width': 102,
#     'height': 76,
#     'x': 258.0,
#     'y': 501.0,
#     'number': 'B915PE163'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_28.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 71,
#     'height': 52,
#     'x': 244.5,
#     'y': 224.0,
#     'number': 'C224MM33'},
#    {'class': 'rect',
#     'width': 77,
#     'height': 48,
#     'x': 530.5,
#     'y': 93.0,
#     'number': 'X596BT76'},
#    {'class': 'rect',
#     'width': 81,
#     'height': 60,
#     'x': 659.5,
#     'y': 401.0,
#     'number': 'C457HP53'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_29.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 88,
#     'height': 72,
#     'x': 403.0,
#     'y': 185.0,
#     'number': 'X949YP159'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_30.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 78,
#     'height': 31,
#     'x': 858.0,
#     'y': 245.5,
#     'number': 'A335EB60'},
#    {'class': 'rect',
#     'width': 57,
#     'height': 42,
#     'x': 767.5,
#     'y': 551.0,
#     'number': 'X914XC48'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_31.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 78,
#     'height': 70,
#     'x': 680.0,
#     'y': 167.0,
#     'number': 'M213TM56'},
#    {'class': 'rect',
#     'width': 75,
#     'height': 32,
#     'x': 184.5,
#     'y': 137.0,
#     'number': 'T719HE83'},
#    {'class': 'rect',
#     'width': 64,
#     'height': 49,
#     'x': 381.0,
#     'y': 154.5,
#     'number': 'T505OP19'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_32.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 98,
#     'height': 75,
#     'x': 460.0,
#     'y': 292.5,
#     'number': 'H369CC174'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_33.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 68,
#     'height': 56,
#     'x': 354.0,
#     'y': 250.0,
#     'number': 'M835BY87'},
#    {'class': 'rect',
#     'width': 89,
#     'height': 76,
#     'x': 941.5,
#     'y': 138.0,
#     'number': 'Y375HT138'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_34.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 98,
#     'height': 77,
#     'x': 668.0,
#     'y': 485.5,
#     'number': 'P197CH46'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_35.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 95,
#     'height': 33,
#     'x': 275.5,
#     'y': 520.5,
#     'number': 'H296OX190'},
#    {'class': 'rect',
#     'width': 101,
#     'height': 49,
#     'x': 914.5,
#     'y': 408.5,
#     'number': 'C871OB123'},
#    {'class': 'rect',
#     'width': 108,
#     'height': 86,
#     'x': 954.0,
#     'y': 290.0,
#     'number': 'T846MH124'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_36.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 95,
#     'height': 39,
#     'x': 765.5,
#     'y': 466.5,
#     'number': 'A352AP28'},
#    {'class': 'rect',
#     'width': 82,
#     'height': 57,
#     'x': 732.0,
#     'y': 354.5,
#     'number': 'X939MO25'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_37.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 71,
#     'height': 55,
#     'x': 454.5,
#     'y': 542.5,
#     'number': 'K029XT44'},
#    {'class': 'rect',
#     'width': 99,
#     'height': 62,
#     'x': 816.5,
#     'y': 111.0,
#     'number': 'X985EA40'},
#    {'class': 'rect',
#     'width': 102,
#     'height': 45,
#     'x': 933.0,
#     'y': 114.5,
#     'number': 'M373CE113'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_38.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 80,
#     'height': 66,
#     'x': 832.0,
#     'y': 593.0,
#     'number': 'K333EC23'},
#    {'class': 'rect',
#     'width': 76,
#     'height': 55,
#     'x': 854.0,
#     'y': 185.5,
#     'number': 'T371TA3'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_39.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 72,
#     'height': 50,
#     'x': 806.0,
#     'y': 311.0,
#     'number': 'K635OK32'},
#    {'class': 'rect',
#     'width': 67,
#     'height': 52,
#     'x': 766.5,
#     'y': 168.0,
#     'number': 'M377PA777'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_40.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 94,
#     'height': 70,
#     'x': 972.0,
#     'y': 470.0,
#     'number': 'X702KT21'},
#    {'class': 'rect',
#     'width': 75,
#     'height': 39,
#     'x': 285.5,
#     'y': 387.5,
#     'number': 'X794PP64'},
#    {'class': 'rect',
#     'width': 95,
#     'height': 62,
#     'x': 966.5,
#     'y': 461.0,
#     'number': 'K556EB75'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_41.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 88,
#     'height': 53,
#     'x': 838.0,
#     'y': 145.5,
#     'number': 'Y263PX161'},
#    {'class': 'rect',
#     'width': 99,
#     'height': 79,
#     'x': 239.5,
#     'y': 311.5,
#     'number': 'O545BY25'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_42.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 82,
#     'height': 69,
#     'x': 764.0,
#     'y': 211.5,
#     'number': 'B392AY55'},
#    {'class': 'rect',
#     'width': 87,
#     'height': 31,
#     'x': 950.5,
#     'y': 261.5,
#     'number': 'O722KA45'},
#    {'class': 'rect',
#     'width': 90,
#     'height': 60,
#     'x': 759.0,
#     'y': 620.0,
#     'number': 'P527XK27'},
#    {'class': 'rect',
#     'width': 103,
#     'height': 39,
#     'x': 522.5,
#     'y': 592.5,
#     'number': 'B232KK44'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_43.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 101,
#     'height': 69,
#     'x': 585.5,
#     'y': 444.5,
#     'number': 'M715EH161'},
#    {'class': 'rect',
#     'width': 95,
#     'height': 70,
#     'x': 746.5,
#     'y': 156.0,
#     'number': 'T110HC50'},
#    {'class': 'rect',
#     'width': 86,
#     'height': 31,
#     'x': 953.0,
#     'y': 101.5,
#     'number': 'C281HA154'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_44.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 65,
#     'height': 47,
#     'x': 874.5,
#     'y': 364.5,
#     'number': 'A449OY63'},
#    {'class': 'rect',
#     'width': 103,
#     'height': 42,
#     'x': 703.5,
#     'y': 343.0,
#     'number': 'H359MB177'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_45.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 64,
#     'height': 46,
#     'x': 570.0,
#     'y': 407.0,
#     'number': 'E625CO95'},
#    {'class': 'rect',
#     'width': 57,
#     'height': 42,
#     'x': 154.5,
#     'y': 502.0,
#     'number': 'T353EH30'},
#    {'class': 'rect',
#     'width': 74,
#     'height': 55,
#     'x': 636.0,
#     'y': 548.5,
#     'number': 'K236MY186'},
#    {'class': 'rect',
#     'width': 65,
#     'height': 60,
#     'x': 427.5,
#     'y': 166.0,
#     'number': 'T841TO95'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_46.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 71,
#     'height': 50,
#     'x': 531.5,
#     'y': 276.0,
#     'number': 'A522AT12'},
#    {'class': 'rect',
#     'width': 100,
#     'height': 67,
#     'x': 521.0,
#     'y': 455.5,
#     'number': 'B496YB190'},
#    {'class': 'rect',
#     'width': 67,
#     'height': 48,
#     'x': 407.5,
#     'y': 102.0,
#     'number': 'M374KO16'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_47.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 92,
#     'height': 57,
#     'x': 215.0,
#     'y': 323.5,
#     'number': 'X736YM32'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_48.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 71,
#     'height': 67,
#     'x': 250.5,
#     'y': 378.5,
#     'number': 'C331XB91'},
#    {'class': 'rect',
#     'width': 97,
#     'height': 62,
#     'x': 869.5,
#     'y': 155.0,
#     'number': 'C446XB142'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_49.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 77,
#     'height': 72,
#     'x': 731.5,
#     'y': 601.0,
#     'number': 'E402AH174'},
#    {'class': 'rect',
#     'width': 61,
#     'height': 46,
#     'x': 651.5,
#     'y': 167.0,
#     'number': 'X277BC121'},
#    {'class': 'rect',
#     'width': 53,
#     'height': 22,
#     'x': 185.5,
#     'y': 269.0,
#     'number': 'K064KO44'},
#    {'class': 'rect',
#     'width': 75,
#     'height': 40,
#     'x': 926.5,
#     'y': 309.0,
#     'number': 'M360AX61'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_50.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 98,
#     'height': 48,
#     'x': 384.0,
#     'y': 289.0,
#     'number': 'K778YT60'},
#    {'class': 'rect',
#     'width': 72,
#     'height': 49,
#     'x': 341.0,
#     'y': 395.5,
#     'number': 'P619EB152'},
#    {'class': 'rect',
#     'width': 107,
#     'height': 69,
#     'x': 954.5,
#     'y': 136.5,
#     'number': 'X083BT134'},
#    {'class': 'rect',
#     'width': 55,
#     'height': 31,
#     'x': 266.5,
#     'y': 266.5,
#     'number': 'A565EC82'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_51.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 93,
#     'height': 47,
#     'x': 659.5,
#     'y': 173.5,
#     'number': 'E640ME90'},
#    {'class': 'rect',
#     'width': 90,
#     'height': 65,
#     'x': 628.0,
#     'y': 387.5,
#     'number': 'A572TK95'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_52.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 102,
#     'height': 45,
#     'x': 688.0,
#     'y': 532.5,
#     'number': 'P199BK190'},
#    {'class': 'rect',
#     'width': 76,
#     'height': 50,
#     'x': 926.0,
#     'y': 429.0,
#     'number': 'H171AC44'},
#    {'class': 'rect',
#     'width': 70,
#     'height': 53,
#     'x': 428.0,
#     'y': 193.5,
#     'number': 'H138OB65'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_53.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 74,
#     'height': 43,
#     'x': 325.0,
#     'y': 217.5,
#     'number': 'B322YA39'},
#    {'class': 'rect',
#     'width': 99,
#     'height': 77,
#     'x': 729.5,
#     'y': 337.5,
#     'number': 'T696TY79'},
#    {'class': 'rect',
#     'width': 89,
#     'height': 63,
#     'x': 882.5,
#     'y': 293.5,
#     'number': 'K171EA80'},
#    {'class': 'rect',
#     'width': 93,
#     'height': 33,
#     'x': 834.5,
#     'y': 162.5,
#     'number': 'X889OE163'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_54.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 103,
#     'height': 63,
#     'x': 564.5,
#     'y': 165.5,
#     'number': 'M252TO69'},
#    {'class': 'rect',
#     'width': 106,
#     'height': 73,
#     'x': 628.0,
#     'y': 90.5,
#     'number': 'T481ET123'},
#    {'class': 'rect',
#     'width': 64,
#     'height': 52,
#     'x': 280.0,
#     'y': 556.0,
#     'number': 'B113PM5'},
#    {'class': 'rect',
#     'width': 77,
#     'height': 63,
#     'x': 794.5,
#     'y': 436.5,
#     'number': 'C733HO98'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_55.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 89,
#     'height': 58,
#     'x': 290.5,
#     'y': 355.0,
#     'number': 'E506HK45'},
#    {'class': 'rect',
#     'width': 61,
#     'height': 46,
#     'x': 819.5,
#     'y': 533.0,
#     'number': 'C110HK69'},
#    {'class': 'rect',
#     'width': 96,
#     'height': 42,
#     'x': 655.0,
#     'y': 472.0,
#     'number': 'C455OC138'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_56.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 72,
#     'height': 62,
#     'x': 884.0,
#     'y': 133.0,
#     'number': 'X010EP16'},
#    {'class': 'rect',
#     'width': 106,
#     'height': 55,
#     'x': 471.0,
#     'y': 95.5,
#     'number': 'B012ET64'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_57.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 93,
#     'height': 38,
#     'x': 710.5,
#     'y': 93.0,
#     'number': 'T439EC74'},
#    {'class': 'rect',
#     'width': 95,
#     'height': 80,
#     'x': 539.5,
#     'y': 153.0,
#     'number': 'O511PX19'},
#    {'class': 'rect',
#     'width': 85,
#     'height': 72,
#     'x': 632.5,
#     'y': 95.0,
#     'number': 'X815MB33'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_58.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 62,
#     'height': 47,
#     'x': 862.0,
#     'y': 431.5,
#     'number': 'O392OX186'},
#    {'class': 'rect',
#     'width': 73,
#     'height': 66,
#     'x': 494.5,
#     'y': 130.0,
#     'number': 'Y188AH164'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_59.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 81,
#     'height': 57,
#     'x': 708.5,
#     'y': 299.5,
#     'number': 'T288TE26'},
#    {'class': 'rect',
#     'width': 56,
#     'height': 53,
#     'x': 486.0,
#     'y': 376.5,
#     'number': 'Y099KK34'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_60.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 95,
#     'height': 32,
#     'x': 535.5,
#     'y': 501.0,
#     'number': 'H557OM93'},
#    {'class': 'rect',
#     'width': 103,
#     'height': 37,
#     'x': 614.5,
#     'y': 46.5,
#     'number': 'K071MB97'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_61.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 61,
#     'height': 51,
#     'x': 431.5,
#     'y': 344.5,
#     'number': 'O269HY161'},
#    {'class': 'rect',
#     'width': 76,
#     'height': 49,
#     'x': 558.0,
#     'y': 496.5,
#     'number': 'X661PY33'},
#    {'class': 'rect',
#     'width': 65,
#     'height': 50,
#     'x': 353.5,
#     'y': 545.0,
#     'number': 'A346KO136'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_62.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 102,
#     'height': 66,
#     'x': 282.0,
#     'y': 507.0,
#     'number': 'O421TC91'},
#    {'class': 'rect',
#     'width': 68,
#     'height': 55,
#     'x': 463.0,
#     'y': 405.5,
#     'number': 'K017HM83'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_63.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 71,
#     'height': 37,
#     'x': 916.5,
#     'y': 545.5,
#     'number': 'Y248YX85'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_64.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 63,
#     'height': 41,
#     'x': 526.5,
#     'y': 83.5,
#     'number': 'C040CT83'},
#    {'class': 'rect',
#     'width': 99,
#     'height': 61,
#     'x': 182.5,
#     'y': 572.5,
#     'number': 'P057XA154'},
#    {'class': 'rect',
#     'width': 106,
#     'height': 69,
#     'x': 805.0,
#     'y': 306.5,
#     'number': 'P196AE164'},
#    {'class': 'rect',
#     'width': 97,
#     'height': 45,
#     'x': 776.5,
#     'y': 167.5,
#     'number': 'H575HH41'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_65.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 91,
#     'height': 50,
#     'x': 625.5,
#     'y': 159.0,
#     'number': 'K593XE57'},
#    {'class': 'rect',
#     'width': 103,
#     'height': 75,
#     'x': 775.5,
#     'y': 179.5,
#     'number': 'Y077CM5'},
#    {'class': 'rect',
#     'width': 79,
#     'height': 43,
#     'x': 697.5,
#     'y': 265.5,
#     'number': 'C578EM750'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_66.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 57,
#     'height': 45,
#     'x': 179.5,
#     'y': 50.5,
#     'number': 'M151EA150'},
#    {'class': 'rect',
#     'width': 91,
#     'height': 68,
#     'x': 775.5,
#     'y': 154.0,
#     'number': 'O526TE125'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_67.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 108,
#     'height': 76,
#     'x': 368.0,
#     'y': 628.0,
#     'number': 'P101TE161'},
#    {'class': 'rect',
#     'width': 84,
#     'height': 75,
#     'x': 906.0,
#     'y': 395.5,
#     'number': 'X117CB159'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_68.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 75,
#     'height': 68,
#     'x': 499.5,
#     'y': 637.0,
#     'number': 'Y979EC186'},
#    {'class': 'rect',
#     'width': 65,
#     'height': 33,
#     'x': 324.5,
#     'y': 575.5,
#     'number': 'E884MY67'},
#    {'class': 'rect',
#     'width': 109,
#     'height': 80,
#     'x': 224.5,
#     'y': 131.0,
#     'number': 'E221CP65'},
#    {'class': 'rect',
#     'width': 77,
#     'height': 57,
#     'x': 162.5,
#     'y': 168.5,
#     'number': 'M376BE63'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_69.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 89,
#     'height': 62,
#     'x': 343.5,
#     'y': 340.0,
#     'number': 'H261PX126'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_70.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 89,
#     'height': 41,
#     'x': 245.5,
#     'y': 398.5,
#     'number': 'H230YE32'},
#    {'class': 'rect',
#     'width': 99,
#     'height': 57,
#     'x': 563.5,
#     'y': 486.5,
#     'number': 'M374PP39'},
#    {'class': 'rect',
#     'width': 68,
#     'height': 63,
#     'x': 406.0,
#     'y': 603.5,
#     'number': 'O622MT52'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_71.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 65,
#     'height': 49,
#     'x': 572.5,
#     'y': 599.5,
#     'number': 'Y337CH49'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_72.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 73,
#     'height': 35,
#     'x': 207.5,
#     'y': 276.5,
#     'number': 'C407EC78'},
#    {'class': 'rect',
#     'width': 107,
#     'height': 63,
#     'x': 317.5,
#     'y': 322.5,
#     'number': 'H743AK44'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_73.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 93,
#     'height': 34,
#     'x': 813.5,
#     'y': 443.0,
#     'number': 'C526YM35'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_74.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 85,
#     'height': 68,
#     'x': 481.5,
#     'y': 194.0,
#     'number': 'M019MM75'},
#    {'class': 'rect',
#     'width': 75,
#     'height': 45,
#     'x': 443.5,
#     'y': 485.5,
#     'number': 'C176MB50'},
#    {'class': 'rect',
#     'width': 81,
#     'height': 51,
#     'x': 919.5,
#     'y': 504.5,
#     'number': 'P926PE74'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_75.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 69,
#     'height': 47,
#     'x': 589.5,
#     'y': 247.5,
#     'number': 'Y927CO150'},
#    {'class': 'rect',
#     'width': 84,
#     'height': 65,
#     'x': 481.0,
#     'y': 408.5,
#     'number': 'Y168OH13'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_76.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 91,
#     'height': 72,
#     'x': 430.5,
#     'y': 167.0,
#     'number': 'H623BM54'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_77.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 75,
#     'height': 35,
#     'x': 404.5,
#     'y': 583.5,
#     'number': 'P561OM99'},
#    {'class': 'rect',
#     'width': 97,
#     'height': 69,
#     'x': 658.5,
#     'y': 339.5,
#     'number': 'P515YP178'},
#    {'class': 'rect',
#     'width': 59,
#     'height': 54,
#     'x': 663.5,
#     'y': 475.0,
#     'number': 'M528PC150'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_78.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 66,
#     'height': 54,
#     'x': 683.0,
#     'y': 436.0,
#     'number': 'A375OX54'},
#    {'class': 'rect',
#     'width': 100,
#     'height': 62,
#     'x': 478.0,
#     'y': 356.0,
#     'number': 'M936BE74'},
#    {'class': 'rect',
#     'width': 87,
#     'height': 52,
#     'x': 193.5,
#     'y': 130.0,
#     'number': 'C050TC125'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_79.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 78,
#     'height': 67,
#     'x': 834.0,
#     'y': 626.5,
#     'number': 'A735HP95'},
#    {'class': 'rect',
#     'width': 94,
#     'height': 69,
#     'x': 203.0,
#     'y': 281.5,
#     'number': 'O083OC6'},
#    {'class': 'rect',
#     'width': 84,
#     'height': 54,
#     'x': 509.0,
#     'y': 357.0,
#     'number': 'O877YY90'},
#    {'class': 'rect',
#     'width': 83,
#     'height': 55,
#     'x': 208.5,
#     'y': 330.5,
#     'number': 'Y050CX8'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_80.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 81,
#     'height': 57,
#     'x': 472.5,
#     'y': 261.5,
#     'number': 'A263MX47'},
#    {'class': 'rect',
#     'width': 81,
#     'height': 71,
#     'x': 358.5,
#     'y': 408.5,
#     'number': 'P901TE102'},
#    {'class': 'rect',
#     'width': 108,
#     'height': 86,
#     'x': 580.0,
#     'y': 615.0,
#     'number': 'M827AE86'},
#    {'class': 'rect',
#     'width': 102,
#     'height': 59,
#     'x': 963.0,
#     'y': 576.5,
#     'number': 'B523XC127'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_81.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 67,
#     'height': 39,
#     'x': 869.5,
#     'y': 422.5,
#     'number': 'X410OM36'},
#    {'class': 'rect',
#     'width': 93,
#     'height': 64,
#     'x': 926.5,
#     'y': 278.0,
#     'number': 'E846EP42'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_82.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 92,
#     'height': 68,
#     'x': 184.0,
#     'y': 553.0,
#     'number': 'P544PE90'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_83.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 68,
#     'height': 51,
#     'x': 741.0,
#     'y': 118.5,
#     'number': 'Y162TP159'},
#    {'class': 'rect',
#     'width': 106,
#     'height': 79,
#     'x': 328.0,
#     'y': 358.5,
#     'number': 'H756AH196'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_84.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 60,
#     'height': 29,
#     'x': 807.0,
#     'y': 371.5,
#     'number': 'B090TX56'},
#    {'class': 'rect',
#     'width': 81,
#     'height': 41,
#     'x': 173.5,
#     'y': 317.5,
#     'number': 'B611YB123'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_85.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 96,
#     'height': 66,
#     'x': 836.0,
#     'y': 503.0,
#     'number': 'T948MM142'},
#    {'class': 'rect',
#     'width': 77,
#     'height': 42,
#     'x': 602.5,
#     'y': 324.0,
#     'number': 'O464YC58'},
#    {'class': 'rect',
#     'width': 67,
#     'height': 25,
#     'x': 268.5,
#     'y': 501.5,
#     'number': 'E362HB82'},
#    {'class': 'rect',
#     'width': 85,
#     'height': 69,
#     'x': 332.5,
#     'y': 479.5,
#     'number': 'Y106PY4'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_86.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 75,
#     'height': 40,
#     'x': 245.5,
#     'y': 216.0,
#     'number': 'Y335EC164'},
#    {'class': 'rect',
#     'width': 67,
#     'height': 40,
#     'x': 902.5,
#     'y': 480.0,
#     'number': 'O171YE123'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_87.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 104,
#     'height': 65,
#     'x': 798.0,
#     'y': 343.5,
#     'number': 'H600BM50'},
#    {'class': 'rect',
#     'width': 62,
#     'height': 46,
#     'x': 192.0,
#     'y': 393.0,
#     'number': 'M069KT63'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_88.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 85,
#     'height': 45,
#     'x': 883.5,
#     'y': 387.5,
#     'number': 'Y602HC80'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_89.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 75,
#     'height': 35,
#     'x': 752.5,
#     'y': 250.5,
#     'number': 'T656CB99'},
#    {'class': 'rect',
#     'width': 79,
#     'height': 40,
#     'x': 459.5,
#     'y': 83.0,
#     'number': 'T219MY44'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_90.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 83,
#     'height': 72,
#     'x': 481.5,
#     'y': 106.0,
#     'number': 'O166XX22'},
#    {'class': 'rect',
#     'width': 63,
#     'height': 52,
#     'x': 401.5,
#     'y': 396.0,
#     'number': 'C431AX49'},
#    {'class': 'rect',
#     'width': 76,
#     'height': 35,
#     'x': 942.0,
#     'y': 239.5,
#     'number': 'M092BP63'},
#    {'class': 'rect',
#     'width': 71,
#     'height': 23,
#     'x': 568.5,
#     'y': 532.5,
#     'number': 'Y898HO60'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_91.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 79,
#     'height': 55,
#     'x': 171.5,
#     'y': 152.5,
#     'number': 'O447OB68'},
#    {'class': 'rect',
#     'width': 84,
#     'height': 75,
#     'x': 680.0,
#     'y': 292.5,
#     'number': 'A662ET45'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_92.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 99,
#     'height': 61,
#     'x': 330.5,
#     'y': 47.5,
#     'number': 'B621MH66'},
#    {'class': 'rect',
#     'width': 95,
#     'height': 71,
#     'x': 352.5,
#     'y': 338.5,
#     'number': 'H775YH96'},
#    {'class': 'rect',
#     'width': 84,
#     'height': 53,
#     'x': 580.0,
#     'y': 463.5,
#     'number': 'P610EA86'},
#    {'class': 'rect',
#     'width': 78,
#     'height': 59,
#     'x': 760.0,
#     'y': 183.5,
#     'number': 'K319TO98'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_93.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 59,
#     'height': 37,
#     'x': 192.5,
#     'y': 459.5,
#     'number': 'X800YP174'},
#    {'class': 'rect',
#     'width': 59,
#     'height': 38,
#     'x': 346.5,
#     'y': 449.0,
#     'number': 'M547BH150'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_94.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 99,
#     'height': 81,
#     'x': 517.5,
#     'y': 145.5,
#     'number': 'H015EX134'},
#    {'class': 'rect',
#     'width': 85,
#     'height': 71,
#     'x': 859.5,
#     'y': 242.5,
#     'number': 'T842KE123'},
#    {'class': 'rect',
#     'width': 80,
#     'height': 50,
#     'x': 669.0,
#     'y': 410.0,
#     'number': 'E713TO92'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_95.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 92,
#     'height': 67,
#     'x': 396.0,
#     'y': 533.5,
#     'number': 'T076YB77'},
#    {'class': 'rect',
#     'width': 98,
#     'height': 53,
#     'x': 242.0,
#     'y': 431.5,
#     'number': 'H285EP29'},
#    {'class': 'rect',
#     'width': 73,
#     'height': 41,
#     'x': 693.5,
#     'y': 553.5,
#     'number': 'Y495MY126'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_96.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 97,
#     'height': 45,
#     'x': 216.5,
#     'y': 420.5,
#     'number': 'E227MY97'},
#    {'class': 'rect',
#     'width': 65,
#     'height': 57,
#     'x': 751.5,
#     'y': 358.5,
#     'number': 'M509XA43'},
#    {'class': 'rect',
#     'width': 96,
#     'height': 58,
#     'x': 969.0,
#     'y': 542.0,
#     'number': 'Y269CA72'},
#    {'class': 'rect',
#     'width': 80,
#     'height': 52,
#     'x': 282.0,
#     'y': 208.0,
#     'number': 'O481TE154'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_97.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 97,
#     'height': 43,
#     'x': 929.5,
#     'y': 455.5,
#     'number': 'K662BE163'},
#    {'class': 'rect',
#     'width': 75,
#     'height': 63,
#     'x': 256.5,
#     'y': 549.5,
#     'number': 'M307AA77'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_98.JPG'},
#  {'annotation': [{'class': 'rect',
#     'width': 66,
#     'height': 51,
#     'x': 406.0,
#     'y': 192.5,
#     'number': 'P488YO76'},
#    {'class': 'rect',
#     'width': 64,
#     'height': 62,
#     'x': 418.0,
#     'y': 208.0,
#     'number': 'E085TE177'}],
#   'class': 'image',
#   'filename': 'data\\synthetic_val\\image_0_99.JPG'}]

# %%
annotation_list = annotation_list_syn.copy()
for el in annotation_list_real:
    el['annotation']['x'] = el['annotation']['x']+el['annotation']['width']/2
    el['annotation']['y'] = el['annotation']['y']+el['annotation']['height']/2
    el['annotation'] = [el['annotation']]
    el['filename'] = el['filename'].replace('xml', 'JPG')
    annotation_list.append(el)

annotation_list[-1]
# Out:
# {'annotation': [{'class': 'rect',
#    'width': 79.0,
#    'height': 45.0,
#    'x': 1068.5,
#    'y': 519.5,
#    'number': 'Y600YY93'}],
#  'class': 'image',
#  'filename': 'data\\train_notations\\Y600YY-93.JPG'}

# %%
len(annotation_list)
# Out:
# 195

# %%
N=0
images = []
categories = [{
              "supercategory": "none",
              "name": "number",
              "id": 1
            }]
annotations = []
for i, el in enumerate(annotation_list):
    images.append({
                  "file_name": (el['filename']).split('\\')[-1],
                  "height": 750,
                  "width": 1200,
                  "id": i+1
                    })
    for j, annot in enumerate(el['annotation']):
        annotations.append({  "id": (j+1)+i*10,
                              "bbox": [
                                annot['x']-annot['width']/2,
                                annot['y']-annot['height']/2,
                                annot['width'],
                                annot['height']
                              ],
                              "image_id": i+1,
                              "segmentation": [],
                              "ignore": 0,
                              "area": annot['width']*annot['height'],
                              "iscrowd": 0,
                              "category_id": 1})


coco_dict = {
              "type": "instances",
              "images": images,
              "categories": categories,
              "annotations": annotations
            }

# %%
coco_dict
# Out:
# {'type': 'instances',
#  'images': [{'file_name': 'image_0_0.JPG',
#    'height': 750,
#    'width': 1200,
#    'id': 1},
#   {'file_name': 'image_0_1.JPG', 'height': 750, 'width': 1200, 'id': 2},
#   {'file_name': 'image_0_2.JPG', 'height': 750, 'width': 1200, 'id': 3},
#   {'file_name': 'image_0_3.JPG', 'height': 750, 'width': 1200, 'id': 4},
#   {'file_name': 'image_0_4.JPG', 'height': 750, 'width': 1200, 'id': 5},
#   {'file_name': 'image_0_5.JPG', 'height': 750, 'width': 1200, 'id': 6},
#   {'file_name': 'image_0_6.JPG', 'height': 750, 'width': 1200, 'id': 7},
#   {'file_name': 'image_0_7.JPG', 'height': 750, 'width': 1200, 'id': 8},
#   {'file_name': 'image_0_8.JPG', 'height': 750, 'width': 1200, 'id': 9},
#   {'file_name': 'image_0_9.JPG', 'height': 750, 'width': 1200, 'id': 10},
#   {'file_name': 'image_0_10.JPG', 'height': 750, 'width': 1200, 'id': 11},
#   {'file_name': 'image_0_11.JPG', 'height': 750, 'width': 1200, 'id': 12},
#   {'file_name': 'image_0_12.JPG', 'height': 750, 'width': 1200, 'id': 13},
#   {'file_name': 'image_0_13.JPG', 'height': 750, 'width': 1200, 'id': 14},
#   {'file_name': 'image_0_14.JPG', 'height': 750, 'width': 1200, 'id': 15},
#   {'file_name': 'image_0_15.JPG', 'height': 750, 'width': 1200, 'id': 16},
#   {'file_name': 'image_0_16.JPG', 'height': 750, 'width': 1200, 'id': 17},
#   {'file_name': 'image_0_17.JPG', 'height': 750, 'width': 1200, 'id': 18},
#   {'file_name': 'image_0_18.JPG', 'height': 750, 'width': 1200, 'id': 19},
#   {'file_name': 'image_0_19.JPG', 'height': 750, 'width': 1200, 'id': 20},
#   {'file_name': 'image_0_20.JPG', 'height': 750, 'width': 1200, 'id': 21},
#   {'file_name': 'image_0_21.JPG', 'height': 750, 'width': 1200, 'id': 22},
#   {'file_name': 'image_0_22.JPG', 'height': 750, 'width': 1200, 'id': 23},
#   {'file_name': 'image_0_23.JPG', 'height': 750, 'width': 1200, 'id': 24},
#   {'file_name': 'image_0_24.JPG', 'height': 750, 'width': 1200, 'id': 25},
#   {'file_name': 'image_0_25.JPG', 'height': 750, 'width': 1200, 'id': 26},
#   {'file_name': 'image_0_26.JPG', 'height': 750, 'width': 1200, 'id': 27},
#   {'file_name': 'image_0_27.JPG', 'height': 750, 'width': 1200, 'id': 28},
#   {'file_name': 'image_0_28.JPG', 'height': 750, 'width': 1200, 'id': 29},
#   {'file_name': 'image_0_29.JPG', 'height': 750, 'width': 1200, 'id': 30},
#   {'file_name': 'image_0_30.JPG', 'height': 750, 'width': 1200, 'id': 31},
#   {'file_name': 'image_0_31.JPG', 'height': 750, 'width': 1200, 'id': 32},
#   {'file_name': 'image_0_32.JPG', 'height': 750, 'width': 1200, 'id': 33},
#   {'file_name': 'image_0_33.JPG', 'height': 750, 'width': 1200, 'id': 34},
#   {'file_name': 'image_0_34.JPG', 'height': 750, 'width': 1200, 'id': 35},
#   {'file_name': 'image_0_35.JPG', 'height': 750, 'width': 1200, 'id': 36},
#   {'file_name': 'image_0_36.JPG', 'height': 750, 'width': 1200, 'id': 37},
#   {'file_name': 'image_0_37.JPG', 'height': 750, 'width': 1200, 'id': 38},
#   {'file_name': 'image_0_38.JPG', 'height': 750, 'width': 1200, 'id': 39},
#   {'file_name': 'image_0_39.JPG', 'height': 750, 'width': 1200, 'id': 40},
#   {'file_name': 'image_0_40.JPG', 'height': 750, 'width': 1200, 'id': 41},
#   {'file_name': 'image_0_41.JPG', 'height': 750, 'width': 1200, 'id': 42},
#   {'file_name': 'image_0_42.JPG', 'height': 750, 'width': 1200, 'id': 43},
#   {'file_name': 'image_0_43.JPG', 'height': 750, 'width': 1200, 'id': 44},
#   {'file_name': 'image_0_44.JPG', 'height': 750, 'width': 1200, 'id': 45},
#   {'file_name': 'image_0_45.JPG', 'height': 750, 'width': 1200, 'id': 46},
#   {'file_name': 'image_0_46.JPG', 'height': 750, 'width': 1200, 'id': 47},
#   {'file_name': 'image_0_47.JPG', 'height': 750, 'width': 1200, 'id': 48},
#   {'file_name': 'image_0_48.JPG', 'height': 750, 'width': 1200, 'id': 49},
#   {'file_name': 'image_0_49.JPG', 'height': 750, 'width': 1200, 'id': 50},
#   {'file_name': 'image_0_50.JPG', 'height': 750, 'width': 1200, 'id': 51},
#   {'file_name': 'image_0_51.JPG', 'height': 750, 'width': 1200, 'id': 52},
#   {'file_name': 'image_0_52.JPG', 'height': 750, 'width': 1200, 'id': 53},
#   {'file_name': 'image_0_53.JPG', 'height': 750, 'width': 1200, 'id': 54},
#   {'file_name': 'image_0_54.JPG', 'height': 750, 'width': 1200, 'id': 55},
#   {'file_name': 'image_0_55.JPG', 'height': 750, 'width': 1200, 'id': 56},
#   {'file_name': 'image_0_56.JPG', 'height': 750, 'width': 1200, 'id': 57},
#   {'file_name': 'image_0_57.JPG', 'height': 750, 'width': 1200, 'id': 58},
#   {'file_name': 'image_0_58.JPG', 'height': 750, 'width': 1200, 'id': 59},
#   {'file_name': 'image_0_59.JPG', 'height': 750, 'width': 1200, 'id': 60},
#   {'file_name': 'image_0_60.JPG', 'height': 750, 'width': 1200, 'id': 61},
#   {'file_name': 'image_0_61.JPG', 'height': 750, 'width': 1200, 'id': 62},
#   {'file_name': 'image_0_62.JPG', 'height': 750, 'width': 1200, 'id': 63},
#   {'file_name': 'image_0_63.JPG', 'height': 750, 'width': 1200, 'id': 64},
#   {'file_name': 'image_0_64.JPG', 'height': 750, 'width': 1200, 'id': 65},
#   {'file_name': 'image_0_65.JPG', 'height': 750, 'width': 1200, 'id': 66},
#   {'file_name': 'image_0_66.JPG', 'height': 750, 'width': 1200, 'id': 67},
#   {'file_name': 'image_0_67.JPG', 'height': 750, 'width': 1200, 'id': 68},
#   {'file_name': 'image_0_68.JPG', 'height': 750, 'width': 1200, 'id': 69},
#   {'file_name': 'image_0_69.JPG', 'height': 750, 'width': 1200, 'id': 70},
#   {'file_name': 'image_0_70.JPG', 'height': 750, 'width': 1200, 'id': 71},
#   {'file_name': 'image_0_71.JPG', 'height': 750, 'width': 1200, 'id': 72},
#   {'file_name': 'image_0_72.JPG', 'height': 750, 'width': 1200, 'id': 73},
#   {'file_name': 'image_0_73.JPG', 'height': 750, 'width': 1200, 'id': 74},
#   {'file_name': 'image_0_74.JPG', 'height': 750, 'width': 1200, 'id': 75},
#   {'file_name': 'image_0_75.JPG', 'height': 750, 'width': 1200, 'id': 76},
#   {'file_name': 'image_0_76.JPG', 'height': 750, 'width': 1200, 'id': 77},
#   {'file_name': 'image_0_77.JPG', 'height': 750, 'width': 1200, 'id': 78},
#   {'file_name': 'image_0_78.JPG', 'height': 750, 'width': 1200, 'id': 79},
#   {'file_name': 'image_0_79.JPG', 'height': 750, 'width': 1200, 'id': 80},
#   {'file_name': 'image_0_80.JPG', 'height': 750, 'width': 1200, 'id': 81},
#   {'file_name': 'image_0_81.JPG', 'height': 750, 'width': 1200, 'id': 82},
#   {'file_name': 'image_0_82.JPG', 'height': 750, 'width': 1200, 'id': 83},
#   {'file_name': 'image_0_83.JPG', 'height': 750, 'width': 1200, 'id': 84},
#   {'file_name': 'image_0_84.JPG', 'height': 750, 'width': 1200, 'id': 85},
#   {'file_name': 'image_0_85.JPG', 'height': 750, 'width': 1200, 'id': 86},
#   {'file_name': 'image_0_86.JPG', 'height': 750, 'width': 1200, 'id': 87},
#   {'file_name': 'image_0_87.JPG', 'height': 750, 'width': 1200, 'id': 88},
#   {'file_name': 'image_0_88.JPG', 'height': 750, 'width': 1200, 'id': 89},
#   {'file_name': 'image_0_89.JPG', 'height': 750, 'width': 1200, 'id': 90},
#   {'file_name': 'image_0_90.JPG', 'height': 750, 'width': 1200, 'id': 91},
#   {'file_name': 'image_0_91.JPG', 'height': 750, 'width': 1200, 'id': 92},
#   {'file_name': 'image_0_92.JPG', 'height': 750, 'width': 1200, 'id': 93},
#   {'file_name': 'image_0_93.JPG', 'height': 750, 'width': 1200, 'id': 94},
#   {'file_name': 'image_0_94.JPG', 'height': 750, 'width': 1200, 'id': 95},
#   {'file_name': 'image_0_95.JPG', 'height': 750, 'width': 1200, 'id': 96},
#   {'file_name': 'image_0_96.JPG', 'height': 750, 'width': 1200, 'id': 97},
#   {'file_name': 'image_0_97.JPG', 'height': 750, 'width': 1200, 'id': 98},
#   {'file_name': 'image_0_98.JPG', 'height': 750, 'width': 1200, 'id': 99},
#   {'file_name': 'image_0_99.JPG', 'height': 750, 'width': 1200, 'id': 100},
#   {'file_name': 'Y592KC-30.JPG', 'height': 750, 'width': 1200, 'id': 101},
#   {'file_name': 'Y592PK-123.JPG', 'height': 750, 'width': 1200, 'id': 102},
#   {'file_name': 'Y592PO-102.JPG', 'height': 750, 'width': 1200, 'id': 103},
#   {'file_name': 'Y592TX-197.JPG', 'height': 750, 'width': 1200, 'id': 104},
#   {'file_name': 'Y592YE-56.JPG', 'height': 750, 'width': 1200, 'id': 105},
#   {'file_name': 'Y593AT-197.JPG', 'height': 750, 'width': 1200, 'id': 106},
#   {'file_name': 'Y593BM-76.JPG', 'height': 750, 'width': 1200, 'id': 107},
#   {'file_name': 'Y593EE-21.JPG', 'height': 750, 'width': 1200, 'id': 108},
#   {'file_name': 'Y593HB-124.JPG', 'height': 750, 'width': 1200, 'id': 109},
#   {'file_name': 'Y593HO-124.JPG', 'height': 750, 'width': 1200, 'id': 110},
#   {'file_name': 'Y593KX-116.JPG', 'height': 750, 'width': 1200, 'id': 111},
#   {'file_name': 'Y593MM-199.JPG', 'height': 750, 'width': 1200, 'id': 112},
#   {'file_name': 'Y593OC-96.JPG', 'height': 750, 'width': 1200, 'id': 113},
#   {'file_name': 'Y593TX-777.JPG', 'height': 750, 'width': 1200, 'id': 114},
#   {'file_name': 'Y593YY-150.JPG', 'height': 750, 'width': 1200, 'id': 115},
#   {'file_name': 'Y593YY-73.JPG', 'height': 750, 'width': 1200, 'id': 116},
#   {'file_name': 'Y594OP-750.JPG', 'height': 750, 'width': 1200, 'id': 117},
#   {'file_name': 'Y594PA-69.JPG', 'height': 750, 'width': 1200, 'id': 118},
#   {'file_name': 'Y594YH-78.JPG', 'height': 750, 'width': 1200, 'id': 119},
#   {'file_name': 'Y595AB-750.JPG', 'height': 750, 'width': 1200, 'id': 120},
#   {'file_name': 'Y595AC-777.JPG', 'height': 750, 'width': 1200, 'id': 121},
#   {'file_name': 'Y595BH-777.JPG', 'height': 750, 'width': 1200, 'id': 122},
#   {'file_name': 'Y595CA-102.JPG', 'height': 750, 'width': 1200, 'id': 123},
#   {'file_name': 'Y595CK-62.JPG', 'height': 750, 'width': 1200, 'id': 124},
#   {'file_name': 'Y595EB-197.JPG', 'height': 750, 'width': 1200, 'id': 125},
#   {'file_name': 'Y595EK-142.JPG', 'height': 750, 'width': 1200, 'id': 126},
#   {'file_name': 'Y595MT-163.JPG', 'height': 750, 'width': 1200, 'id': 127},
#   {'file_name': 'Y595MX-96.JPG', 'height': 750, 'width': 1200, 'id': 128},
#   {'file_name': 'Y595OE-102.JPG', 'height': 750, 'width': 1200, 'id': 129},
#   {'file_name': 'Y595PA-74.JPG', 'height': 750, 'width': 1200, 'id': 130},
#   {'file_name': 'Y595YA-36.JPG', 'height': 750, 'width': 1200, 'id': 131},
#   {'file_name': 'Y596AT-163.JPG', 'height': 750, 'width': 1200, 'id': 132},
#   {'file_name': 'Y596BK-125.JPG', 'height': 750, 'width': 1200, 'id': 133},
#   {'file_name': 'Y596CT-102.JPG', 'height': 750, 'width': 1200, 'id': 134},
#   {'file_name': 'Y596EA-799.JPG', 'height': 750, 'width': 1200, 'id': 135},
#   {'file_name': 'Y596KO-116.JPG', 'height': 750, 'width': 1200, 'id': 136},
#   {'file_name': 'Y596MB-799.JPG', 'height': 750, 'width': 1200, 'id': 137},
#   {'file_name': 'Y596MP-125.JPG', 'height': 750, 'width': 1200, 'id': 138},
#   {'file_name': 'Y596OO-43.JPG', 'height': 750, 'width': 1200, 'id': 139},
#   {'file_name': 'Y596OO-750.JPG', 'height': 750, 'width': 1200, 'id': 140},
#   {'file_name': 'Y596YH-190.JPG', 'height': 750, 'width': 1200, 'id': 141},
#   {'file_name': 'Y597AX-799.JPG', 'height': 750, 'width': 1200, 'id': 142},
#   {'file_name': 'Y597BP-102.JPG', 'height': 750, 'width': 1200, 'id': 143},
#   {'file_name': 'Y597EA-178.JPG', 'height': 750, 'width': 1200, 'id': 144},
#   {'file_name': 'Y597EC-777.JPG', 'height': 750, 'width': 1200, 'id': 145},
#   {'file_name': 'Y597EM-43.JPG', 'height': 750, 'width': 1200, 'id': 146},
#   {'file_name': 'Y597EP-62.JPG', 'height': 750, 'width': 1200, 'id': 147},
#   {'file_name': 'Y597HB-33.JPG', 'height': 750, 'width': 1200, 'id': 148},
#   {'file_name': 'Y597KM-51.JPG', 'height': 750, 'width': 1200, 'id': 149},
#   {'file_name': 'Y597KP-51.JPG', 'height': 750, 'width': 1200, 'id': 150},
#   {'file_name': 'Y597MO-190.JPG', 'height': 750, 'width': 1200, 'id': 151},
#   {'file_name': 'Y597XC-36.JPG', 'height': 750, 'width': 1200, 'id': 152},
#   {'file_name': 'Y597YA-125.JPG', 'height': 750, 'width': 1200, 'id': 153},
#   {'file_name': 'Y597YO-178.JPG', 'height': 750, 'width': 1200, 'id': 154},
#   {'file_name': 'Y597YY-77.JPG', 'height': 750, 'width': 1200, 'id': 155},
#   {'file_name': 'Y598CO-178.JPG', 'height': 750, 'width': 1200, 'id': 156},
#   {'file_name': 'Y598CT-163.JPG', 'height': 750, 'width': 1200, 'id': 157},
#   {'file_name': 'Y598EC-777.JPG', 'height': 750, 'width': 1200, 'id': 158},
#   {'file_name': 'Y598HH-163.JPG', 'height': 750, 'width': 1200, 'id': 159},
#   {'file_name': 'Y598PX-116.JPG', 'height': 750, 'width': 1200, 'id': 160},
#   {'file_name': 'Y598XC-777.JPG', 'height': 750, 'width': 1200, 'id': 161},
#   {'file_name': 'Y598XE-163.JPG', 'height': 750, 'width': 1200, 'id': 162},
#   {'file_name': 'Y599AP-102.JPG', 'height': 750, 'width': 1200, 'id': 163},
#   {'file_name': 'Y599BA-138.JPG', 'height': 750, 'width': 1200, 'id': 164},
#   {'file_name': 'Y599CM-25.JPG', 'height': 750, 'width': 1200, 'id': 165},
#   {'file_name': 'Y599CM-777.JPG', 'height': 750, 'width': 1200, 'id': 166},
#   {'file_name': 'Y599EB-60.JPG', 'height': 750, 'width': 1200, 'id': 167},
#   {'file_name': 'Y599HB-98.JPG', 'height': 750, 'width': 1200, 'id': 168},
#   {'file_name': 'Y599HC-777.JPG', 'height': 750, 'width': 1200, 'id': 169},
#   {'file_name': 'Y599KT-750.JPG', 'height': 750, 'width': 1200, 'id': 170},
#   {'file_name': 'Y599PM-102.JPG', 'height': 750, 'width': 1200, 'id': 171},
#   {'file_name': 'Y599XO-174.JPG', 'height': 750, 'width': 1200, 'id': 172},
#   {'file_name': 'Y599XX-161.JPG', 'height': 750, 'width': 1200, 'id': 173},
#   {'file_name': 'Y599YA-163.JPG', 'height': 750, 'width': 1200, 'id': 174},
#   {'file_name': 'Y599YT-190.JPG', 'height': 750, 'width': 1200, 'id': 175},
#   {'file_name': 'Y600AH-98.JPG', 'height': 750, 'width': 1200, 'id': 176},
#   {'file_name': 'Y600AK-102.JPG', 'height': 750, 'width': 1200, 'id': 177},
#   {'file_name': 'Y600AK-186.JPG', 'height': 750, 'width': 1200, 'id': 178},
#   {'file_name': 'Y600AK-98.JPG', 'height': 750, 'width': 1200, 'id': 179},
#   {'file_name': 'Y600AM-174.JPG', 'height': 750, 'width': 1200, 'id': 180},
#   {'file_name': 'Y600BK-35.JPG', 'height': 750, 'width': 1200, 'id': 181},
#   {'file_name': 'Y600BM-750.JPG', 'height': 750, 'width': 1200, 'id': 182},
#   {'file_name': 'Y600BO-35.JPG', 'height': 750, 'width': 1200, 'id': 183},
#   {'file_name': 'Y600BO-777.JPG', 'height': 750, 'width': 1200, 'id': 184},
#   {'file_name': 'Y600BY-50.JPG', 'height': 750, 'width': 1200, 'id': 185},
#   {'file_name': 'Y600YA-197.JPG', 'height': 750, 'width': 1200, 'id': 186},
#   {'file_name': 'Y600YE-61.JPG', 'height': 750, 'width': 1200, 'id': 187},
#   {'file_name': 'Y600YH-102.JPG', 'height': 750, 'width': 1200, 'id': 188},
#   {'file_name': 'Y600YM-190.JPG', 'height': 750, 'width': 1200, 'id': 189},
#   {'file_name': 'Y600YY-54.JPG', 'height': 750, 'width': 1200, 'id': 190},
#   {'file_name': 'Y600YY-64.JPG', 'height': 750, 'width': 1200, 'id': 191},
#   {'file_name': 'Y600YY-71.JPG', 'height': 750, 'width': 1200, 'id': 192},
#   {'file_name': 'Y600YY-77.JPG', 'height': 750, 'width': 1200, 'id': 193},
#   {'file_name': 'Y600YY-86.JPG', 'height': 750, 'width': 1200, 'id': 194},
#   {'file_name': 'Y600YY-93.JPG', 'height': 750, 'width': 1200, 'id': 195}],
#  'categories': [{'supercategory': 'none', 'name': 'number', 'id': 1}],
#  'annotations': [{'id': 1,
#    'bbox': [669.0, 533.0, 98, 82],
#    'image_id': 1,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8036,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 2,
#    'bbox': [829.0, 149.0, 65, 57],
#    'image_id': 1,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3705,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 3,
#    'bbox': [637.0, 545.0, 72, 66],
#    'image_id': 1,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4752,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 4,
#    'bbox': [710.0, 75.0, 103, 74],
#    'image_id': 1,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7622,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 11,
#    'bbox': [159.0, 554.0, 90, 42],
#    'image_id': 2,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3780,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 21,
#    'bbox': [353.0, 583.0, 69, 59],
#    'image_id': 3,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4071,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 22,
#    'bbox': [209.0, 83.0, 70, 59],
#    'image_id': 3,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4130,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 31,
#    'bbox': [823.0, 389.0, 55, 36],
#    'image_id': 4,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1980,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 32,
#    'bbox': [673.0, 303.0, 69, 46],
#    'image_id': 4,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3174,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 41,
#    'bbox': [683.0, 330.0, 79, 31],
#    'image_id': 5,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2449,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 42,
#    'bbox': [564.0, 184.0, 75, 45],
#    'image_id': 5,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3375,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 43,
#    'bbox': [230.0, 592.0, 83, 52],
#    'image_id': 5,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4316,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 44,
#    'bbox': [564.0, 160.0, 88, 60],
#    'image_id': 5,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5280,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 51,
#    'bbox': [820.0, 571.0, 82, 69],
#    'image_id': 6,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5658,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 52,
#    'bbox': [792.0, 368.0, 75, 57],
#    'image_id': 6,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4275,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 53,
#    'bbox': [264.0, 414.0, 71, 28],
#    'image_id': 6,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1988,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 54,
#    'bbox': [282.0, 491.0, 107, 65],
#    'image_id': 6,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6955,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 61,
#    'bbox': [778.0, 287.0, 71, 58],
#    'image_id': 7,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4118,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 62,
#    'bbox': [473.0, 371.0, 73, 72],
#    'image_id': 7,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5256,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 63,
#    'bbox': [885.0, 82.0, 93, 56],
#    'image_id': 7,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5208,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 71,
#    'bbox': [368.0, 267.0, 99, 29],
#    'image_id': 8,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2871,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 72,
#    'bbox': [143.0, 333.0, 92, 74],
#    'image_id': 8,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6808,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 73,
#    'bbox': [155.0, 145.0, 86, 60],
#    'image_id': 8,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5160,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 74,
#    'bbox': [570.0, 105.0, 75, 45],
#    'image_id': 8,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3375,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 81,
#    'bbox': [907.0, 384.0, 82, 55],
#    'image_id': 9,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4510,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 82,
#    'bbox': [787.0, 230.0, 98, 71],
#    'image_id': 9,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6958,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 91,
#    'bbox': [664.0, 489.0, 88, 72],
#    'image_id': 10,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6336,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 92,
#    'bbox': [108.0, 226.0, 78, 49],
#    'image_id': 10,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3822,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 101,
#    'bbox': [411.0, 463.0, 67, 51],
#    'image_id': 11,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3417,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 102,
#    'bbox': [659.0, 298.0, 94, 78],
#    'image_id': 11,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7332,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 111,
#    'bbox': [849.0, 434.0, 90, 33],
#    'image_id': 12,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2970,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 112,
#    'bbox': [404.0, 609.0, 71, 67],
#    'image_id': 12,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4757,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 113,
#    'bbox': [821.0, 394.0, 102, 85],
#    'image_id': 12,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8670,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 121,
#    'bbox': [224.0, 286.0, 59, 37],
#    'image_id': 13,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2183,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 122,
#    'bbox': [824.0, 324.0, 69, 41],
#    'image_id': 13,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2829,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 131,
#    'bbox': [647.0, 271.0, 67, 58],
#    'image_id': 14,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3886,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 132,
#    'bbox': [418.0, 170.0, 96, 31],
#    'image_id': 14,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2976,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 133,
#    'bbox': [716.0, 427.0, 63, 43],
#    'image_id': 14,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2709,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 141,
#    'bbox': [294.0, 266.0, 70, 54],
#    'image_id': 15,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3780,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 142,
#    'bbox': [176.0, 201.0, 90, 65],
#    'image_id': 15,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5850,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 143,
#    'bbox': [346.0, 412.0, 97, 45],
#    'image_id': 15,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4365,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 151,
#    'bbox': [889.0, 174.0, 92, 64],
#    'image_id': 16,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5888,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 161,
#    'bbox': [943.0, 253.0, 102, 53],
#    'image_id': 17,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5406,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 162,
#    'bbox': [650.0, 182.0, 55, 33],
#    'image_id': 17,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1815,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 163,
#    'bbox': [397.0, 288.0, 89, 32],
#    'image_id': 17,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2848,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 171,
#    'bbox': [346.0, 97.0, 87, 57],
#    'image_id': 18,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4959,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 172,
#    'bbox': [435.0, 147.0, 74, 70],
#    'image_id': 18,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5180,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 173,
#    'bbox': [575.0, 239.0, 59, 40],
#    'image_id': 18,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2360,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 174,
#    'bbox': [223.0, 250.0, 62, 39],
#    'image_id': 18,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2418,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 181,
#    'bbox': [688.0, 586.0, 87, 75],
#    'image_id': 19,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6525,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 182,
#    'bbox': [321.0, 299.0, 87, 57],
#    'image_id': 19,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4959,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 183,
#    'bbox': [819.0, 359.0, 89, 37],
#    'image_id': 19,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3293,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 184,
#    'bbox': [854.0, 223.0, 69, 51],
#    'image_id': 19,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3519,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 191,
#    'bbox': [560.0, 40.0, 91, 55],
#    'image_id': 20,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5005,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 201,
#    'bbox': [268.0, 422.0, 98, 55],
#    'image_id': 21,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5390,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 202,
#    'bbox': [323.0, 83.0, 55, 51],
#    'image_id': 21,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2805,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 203,
#    'bbox': [592.0, 459.0, 105, 63],
#    'image_id': 21,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6615,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 204,
#    'bbox': [388.0, 406.0, 77, 47],
#    'image_id': 21,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3619,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 211,
#    'bbox': [390.0, 176.0, 76, 63],
#    'image_id': 22,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4788,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 221,
#    'bbox': [802.0, 304.0, 60, 35],
#    'image_id': 23,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2100,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 222,
#    'bbox': [309.0, 172.0, 81, 63],
#    'image_id': 23,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5103,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 231,
#    'bbox': [474.0, 286.0, 56, 44],
#    'image_id': 24,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2464,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 232,
#    'bbox': [367.0, 418.0, 86, 76],
#    'image_id': 24,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6536,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 233,
#    'bbox': [611.0, 297.0, 78, 64],
#    'image_id': 24,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4992,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 241,
#    'bbox': [216.0, 435.0, 63, 36],
#    'image_id': 25,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2268,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 242,
#    'bbox': [449.0, 155.0, 88, 35],
#    'image_id': 25,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3080,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 243,
#    'bbox': [820.0, 274.0, 65, 37],
#    'image_id': 25,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2405,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 244,
#    'bbox': [748.0, 381.0, 64, 61],
#    'image_id': 25,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3904,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 251,
#    'bbox': [687.0, 364.0, 57, 39],
#    'image_id': 26,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2223,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 252,
#    'bbox': [503.0, 63.0, 92, 79],
#    'image_id': 26,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7268,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 253,
#    'bbox': [377.0, 476.0, 100, 53],
#    'image_id': 26,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5300,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 254,
#    'bbox': [599.0, 136.0, 73, 56],
#    'image_id': 26,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4088,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 261,
#    'bbox': [483.0, 416.0, 63, 57],
#    'image_id': 27,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3591,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 262,
#    'bbox': [569.0, 335.0, 71, 58],
#    'image_id': 27,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4118,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 271,
#    'bbox': [753.0, 132.0, 88, 57],
#    'image_id': 28,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5016,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 272,
#    'bbox': [535.0, 440.0, 63, 55],
#    'image_id': 28,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3465,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 273,
#    'bbox': [815.0, 562.0, 95, 38],
#    'image_id': 28,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3610,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 274,
#    'bbox': [233.0, 65.0, 104, 81],
#    'image_id': 28,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8424,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 281,
#    'bbox': [214.0, 542.0, 92, 63],
#    'image_id': 29,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5796,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 282,
#    'bbox': [188.0, 539.0, 75, 43],
#    'image_id': 29,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3225,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 283,
#    'bbox': [555.0, 159.0, 98, 73],
#    'image_id': 29,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7154,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 284,
#    'bbox': [207.0, 463.0, 102, 76],
#    'image_id': 29,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7752,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 291,
#    'bbox': [209.0, 198.0, 71, 52],
#    'image_id': 30,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3692,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 292,
#    'bbox': [492.0, 69.0, 77, 48],
#    'image_id': 30,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3696,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 293,
#    'bbox': [619.0, 371.0, 81, 60],
#    'image_id': 30,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4860,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 301,
#    'bbox': [359.0, 149.0, 88, 72],
#    'image_id': 31,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6336,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 311,
#    'bbox': [819.0, 230.0, 78, 31],
#    'image_id': 32,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2418,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 312,
#    'bbox': [739.0, 530.0, 57, 42],
#    'image_id': 32,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2394,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 321,
#    'bbox': [641.0, 132.0, 78, 70],
#    'image_id': 33,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5460,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 322,
#    'bbox': [147.0, 121.0, 75, 32],
#    'image_id': 33,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2400,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 323,
#    'bbox': [349.0, 130.0, 64, 49],
#    'image_id': 33,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3136,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 331,
#    'bbox': [411.0, 255.0, 98, 75],
#    'image_id': 34,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7350,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 341,
#    'bbox': [320.0, 222.0, 68, 56],
#    'image_id': 35,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3808,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 342,
#    'bbox': [897.0, 100.0, 89, 76],
#    'image_id': 35,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6764,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 351,
#    'bbox': [619.0, 447.0, 98, 77],
#    'image_id': 36,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7546,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 361,
#    'bbox': [228.0, 504.0, 95, 33],
#    'image_id': 37,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3135,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 362,
#    'bbox': [864.0, 384.0, 101, 49],
#    'image_id': 37,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4949,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 363,
#    'bbox': [900.0, 247.0, 108, 86],
#    'image_id': 37,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 9288,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 371,
#    'bbox': [718.0, 447.0, 95, 39],
#    'image_id': 38,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3705,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 372,
#    'bbox': [691.0, 326.0, 82, 57],
#    'image_id': 38,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4674,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 381,
#    'bbox': [419.0, 515.0, 71, 55],
#    'image_id': 39,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3905,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 382,
#    'bbox': [767.0, 80.0, 99, 62],
#    'image_id': 39,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6138,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 383,
#    'bbox': [882.0, 92.0, 102, 45],
#    'image_id': 39,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4590,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 391,
#    'bbox': [792.0, 560.0, 80, 66],
#    'image_id': 40,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5280,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 392,
#    'bbox': [816.0, 158.0, 76, 55],
#    'image_id': 40,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4180,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 401,
#    'bbox': [770.0, 286.0, 72, 50],
#    'image_id': 41,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3600,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 402,
#    'bbox': [733.0, 142.0, 67, 52],
#    'image_id': 41,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3484,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 411,
#    'bbox': [925.0, 435.0, 94, 70],
#    'image_id': 42,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6580,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 412,
#    'bbox': [248.0, 368.0, 75, 39],
#    'image_id': 42,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2925,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 413,
#    'bbox': [919.0, 430.0, 95, 62],
#    'image_id': 42,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5890,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 421,
#    'bbox': [794.0, 119.0, 88, 53],
#    'image_id': 43,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4664,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 422,
#    'bbox': [190.0, 272.0, 99, 79],
#    'image_id': 43,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7821,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 431,
#    'bbox': [723.0, 177.0, 82, 69],
#    'image_id': 44,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5658,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 432,
#    'bbox': [907.0, 246.0, 87, 31],
#    'image_id': 44,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2697,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 433,
#    'bbox': [714.0, 590.0, 90, 60],
#    'image_id': 44,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5400,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 434,
#    'bbox': [471.0, 573.0, 103, 39],
#    'image_id': 44,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4017,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 441,
#    'bbox': [535.0, 410.0, 101, 69],
#    'image_id': 45,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6969,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 442,
#    'bbox': [699.0, 121.0, 95, 70],
#    'image_id': 45,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6650,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 443,
#    'bbox': [910.0, 86.0, 86, 31],
#    'image_id': 45,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2666,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 451,
#    'bbox': [842.0, 341.0, 65, 47],
#    'image_id': 46,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3055,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 452,
#    'bbox': [652.0, 322.0, 103, 42],
#    'image_id': 46,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4326,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 461,
#    'bbox': [538.0, 384.0, 64, 46],
#    'image_id': 47,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2944,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 462,
#    'bbox': [126.0, 481.0, 57, 42],
#    'image_id': 47,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2394,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 463,
#    'bbox': [599.0, 521.0, 74, 55],
#    'image_id': 47,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4070,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 464,
#    'bbox': [395.0, 136.0, 65, 60],
#    'image_id': 47,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3900,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 471,
#    'bbox': [496.0, 251.0, 71, 50],
#    'image_id': 48,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3550,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 472,
#    'bbox': [471.0, 422.0, 100, 67],
#    'image_id': 48,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6700,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 473,
#    'bbox': [374.0, 78.0, 67, 48],
#    'image_id': 48,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3216,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 481,
#    'bbox': [169.0, 295.0, 92, 57],
#    'image_id': 49,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5244,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 491,
#    'bbox': [215.0, 345.0, 71, 67],
#    'image_id': 50,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4757,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 492,
#    'bbox': [821.0, 124.0, 97, 62],
#    'image_id': 50,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6014,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 501,
#    'bbox': [693.0, 565.0, 77, 72],
#    'image_id': 51,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5544,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 502,
#    'bbox': [621.0, 144.0, 61, 46],
#    'image_id': 51,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2806,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 503,
#    'bbox': [159.0, 258.0, 53, 22],
#    'image_id': 51,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1166,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 504,
#    'bbox': [889.0, 289.0, 75, 40],
#    'image_id': 51,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3000,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 511,
#    'bbox': [335.0, 265.0, 98, 48],
#    'image_id': 52,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4704,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 512,
#    'bbox': [305.0, 371.0, 72, 49],
#    'image_id': 52,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3528,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 513,
#    'bbox': [901.0, 102.0, 107, 69],
#    'image_id': 52,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7383,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 514,
#    'bbox': [239.0, 251.0, 55, 31],
#    'image_id': 52,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1705,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 521,
#    'bbox': [613.0, 150.0, 93, 47],
#    'image_id': 53,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4371,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 522,
#    'bbox': [583.0, 355.0, 90, 65],
#    'image_id': 53,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5850,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 531,
#    'bbox': [637.0, 510.0, 102, 45],
#    'image_id': 54,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4590,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 532,
#    'bbox': [888.0, 404.0, 76, 50],
#    'image_id': 54,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3800,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 533,
#    'bbox': [393.0, 167.0, 70, 53],
#    'image_id': 54,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3710,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 541,
#    'bbox': [288.0, 196.0, 74, 43],
#    'image_id': 55,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3182,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 542,
#    'bbox': [680.0, 299.0, 99, 77],
#    'image_id': 55,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7623,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 543,
#    'bbox': [838.0, 262.0, 89, 63],
#    'image_id': 55,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5607,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 544,
#    'bbox': [788.0, 146.0, 93, 33],
#    'image_id': 55,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3069,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 551,
#    'bbox': [513.0, 134.0, 103, 63],
#    'image_id': 56,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6489,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 552,
#    'bbox': [575.0, 54.0, 106, 73],
#    'image_id': 56,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7738,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 553,
#    'bbox': [248.0, 530.0, 64, 52],
#    'image_id': 56,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3328,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 554,
#    'bbox': [756.0, 405.0, 77, 63],
#    'image_id': 56,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4851,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 561,
#    'bbox': [246.0, 326.0, 89, 58],
#    'image_id': 57,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5162,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 562,
#    'bbox': [789.0, 510.0, 61, 46],
#    'image_id': 57,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2806,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 563,
#    'bbox': [607.0, 451.0, 96, 42],
#    'image_id': 57,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4032,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 571,
#    'bbox': [848.0, 102.0, 72, 62],
#    'image_id': 58,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4464,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 572,
#    'bbox': [418.0, 68.0, 106, 55],
#    'image_id': 58,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5830,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 581,
#    'bbox': [664.0, 74.0, 93, 38],
#    'image_id': 59,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3534,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 582,
#    'bbox': [492.0, 113.0, 95, 80],
#    'image_id': 59,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7600,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 583,
#    'bbox': [590.0, 59.0, 85, 72],
#    'image_id': 59,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6120,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 591,
#    'bbox': [831.0, 408.0, 62, 47],
#    'image_id': 60,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2914,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 592,
#    'bbox': [458.0, 97.0, 73, 66],
#    'image_id': 60,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4818,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 601,
#    'bbox': [668.0, 271.0, 81, 57],
#    'image_id': 61,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4617,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 602,
#    'bbox': [458.0, 350.0, 56, 53],
#    'image_id': 61,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2968,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 611,
#    'bbox': [488.0, 485.0, 95, 32],
#    'image_id': 62,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3040,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 612,
#    'bbox': [563.0, 28.0, 103, 37],
#    'image_id': 62,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3811,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 621,
#    'bbox': [401.0, 319.0, 61, 51],
#    'image_id': 63,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3111,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 622,
#    'bbox': [520.0, 472.0, 76, 49],
#    'image_id': 63,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3724,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 623,
#    'bbox': [321.0, 520.0, 65, 50],
#    'image_id': 63,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3250,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 631,
#    'bbox': [231.0, 474.0, 102, 66],
#    'image_id': 64,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6732,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 632,
#    'bbox': [429.0, 378.0, 68, 55],
#    'image_id': 64,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3740,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 641,
#    'bbox': [881.0, 527.0, 71, 37],
#    'image_id': 65,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2627,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 651,
#    'bbox': [495.0, 63.0, 63, 41],
#    'image_id': 66,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2583,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 652,
#    'bbox': [133.0, 542.0, 99, 61],
#    'image_id': 66,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6039,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 653,
#    'bbox': [752.0, 272.0, 106, 69],
#    'image_id': 66,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7314,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 654,
#    'bbox': [728.0, 145.0, 97, 45],
#    'image_id': 66,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4365,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 661,
#    'bbox': [580.0, 134.0, 91, 50],
#    'image_id': 67,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4550,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 662,
#    'bbox': [724.0, 142.0, 103, 75],
#    'image_id': 67,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7725,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 663,
#    'bbox': [658.0, 244.0, 79, 43],
#    'image_id': 67,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3397,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 671,
#    'bbox': [151.0, 28.0, 57, 45],
#    'image_id': 68,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2565,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 672,
#    'bbox': [730.0, 120.0, 91, 68],
#    'image_id': 68,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6188,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 681,
#    'bbox': [314.0, 590.0, 108, 76],
#    'image_id': 69,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8208,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 682,
#    'bbox': [864.0, 358.0, 84, 75],
#    'image_id': 69,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6300,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 691,
#    'bbox': [462.0, 603.0, 75, 68],
#    'image_id': 70,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5100,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 692,
#    'bbox': [292.0, 559.0, 65, 33],
#    'image_id': 70,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2145,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 693,
#    'bbox': [170.0, 91.0, 109, 80],
#    'image_id': 70,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8720,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 694,
#    'bbox': [124.0, 140.0, 77, 57],
#    'image_id': 70,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4389,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 701,
#    'bbox': [299.0, 309.0, 89, 62],
#    'image_id': 71,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5518,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 711,
#    'bbox': [201.0, 378.0, 89, 41],
#    'image_id': 72,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3649,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 712,
#    'bbox': [514.0, 458.0, 99, 57],
#    'image_id': 72,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5643,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 713,
#    'bbox': [372.0, 572.0, 68, 63],
#    'image_id': 72,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4284,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 721,
#    'bbox': [540.0, 575.0, 65, 49],
#    'image_id': 73,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3185,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 731,
#    'bbox': [171.0, 259.0, 73, 35],
#    'image_id': 74,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2555,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 732,
#    'bbox': [264.0, 291.0, 107, 63],
#    'image_id': 74,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6741,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 741,
#    'bbox': [767.0, 426.0, 93, 34],
#    'image_id': 75,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3162,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 751,
#    'bbox': [439.0, 160.0, 85, 68],
#    'image_id': 76,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5780,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 752,
#    'bbox': [406.0, 463.0, 75, 45],
#    'image_id': 76,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3375,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 753,
#    'bbox': [879.0, 479.0, 81, 51],
#    'image_id': 76,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4131,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 761,
#    'bbox': [555.0, 224.0, 69, 47],
#    'image_id': 77,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3243,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 762,
#    'bbox': [439.0, 376.0, 84, 65],
#    'image_id': 77,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5460,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 771,
#    'bbox': [385.0, 131.0, 91, 72],
#    'image_id': 78,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6552,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 781,
#    'bbox': [367.0, 566.0, 75, 35],
#    'image_id': 79,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2625,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 782,
#    'bbox': [610.0, 305.0, 97, 69],
#    'image_id': 79,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6693,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 783,
#    'bbox': [634.0, 448.0, 59, 54],
#    'image_id': 79,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3186,
#    'iscrowd': 0,
#    'category_id': 1},
# ...
#    'bbox': [281.0, 562.0, 239.0, 63.0],
#    'image_id': 103,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 15057.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1031,
#    'bbox': [398.0, 361.0, 224.0, 58.0],
#    'image_id': 104,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 12992.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1041,
#    'bbox': [806.0, 507.0, 85.0, 27.0],
#    'image_id': 105,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2295.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1051,
#    'bbox': [408.0, 350.0, 253.0, 68.0],
#    'image_id': 106,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 17204.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1061,
#    'bbox': [507.0, 582.0, 182.0, 33.0],
#    'image_id': 107,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6006.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1071,
#    'bbox': [243.0, 586.0, 142.0, 34.0],
#    'image_id': 108,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4828.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1081,
#    'bbox': [949.0, 652.0, 60.0, 23.0],
#    'image_id': 109,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1380.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1091,
#    'bbox': [603.0, 516.0, 134.0, 32.0],
#    'image_id': 110,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4288.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1101,
#    'bbox': [488.0, 328.0, 288.0, 46.0],
#    'image_id': 111,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 13248.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1111,
#    'bbox': [746.0, 510.0, 193.0, 35.0],
#    'image_id': 112,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6755.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1121,
#    'bbox': [206.0, 517.0, 83.0, 26.0],
#    'image_id': 113,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2158.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1131,
#    'bbox': [890.0, 396.0, 162.0, 79.0],
#    'image_id': 114,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 12798.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1141,
#    'bbox': [607.0, 414.0, 166.0, 33.0],
#    'image_id': 115,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5478.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1151,
#    'bbox': [761.0, 446.0, 181.0, 38.0],
#    'image_id': 116,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6878.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1161,
#    'bbox': [136.0, 514.0, 89.0, 33.0],
#    'image_id': 117,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2937.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1171,
#    'bbox': [866.0, 477.0, 169.0, 52.0],
#    'image_id': 118,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8788.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1181,
#    'bbox': [844.0, 575.0, 121.0, 36.0],
#    'image_id': 119,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4356.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1191,
#    'bbox': [390.0, 484.0, 192.0, 44.0],
#    'image_id': 120,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8448.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1201,
#    'bbox': [143.0, 462.0, 113.0, 30.0],
#    'image_id': 121,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3390.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1211,
#    'bbox': [890.0, 422.0, 157.0, 74.0],
#    'image_id': 122,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 11618.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1221,
#    'bbox': [339.0, 414.0, 264.0, 53.0],
#    'image_id': 123,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 13992.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1231,
#    'bbox': [369.0, 524.0, 198.0, 48.0],
#    'image_id': 124,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 9504.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1241,
#    'bbox': [635.0, 401.0, 126.0, 38.0],
#    'image_id': 125,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4788.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1251,
#    'bbox': [918.0, 344.0, 131.0, 66.0],
#    'image_id': 126,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8646.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1261,
#    'bbox': [339.0, 523.0, 225.0, 56.0],
#    'image_id': 127,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 12600.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1271,
#    'bbox': [681.0, 402.0, 137.0, 30.0],
#    'image_id': 128,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4110.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1281,
#    'bbox': [254.0, 414.0, 120.0, 37.0],
#    'image_id': 129,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4440.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1291,
#    'bbox': [546.0, 372.0, 258.0, 53.0],
#    'image_id': 130,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 13674.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1301,
#    'bbox': [190.0, 536.0, 134.0, 70.0],
#    'image_id': 131,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 9380.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1311,
#    'bbox': [404.0, 454.0, 192.0, 39.0],
#    'image_id': 132,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7488.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1321,
#    'bbox': [500.0, 521.0, 108.0, 25.0],
#    'image_id': 133,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2700.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1331,
#    'bbox': [929.0, 586.0, 61.0, 22.0],
#    'image_id': 134,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1342.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1341,
#    'bbox': [450.0, 467.0, 179.0, 42.0],
#    'image_id': 135,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7518.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1351,
#    'bbox': [184.0, 632.0, 74.0, 21.0],
#    'image_id': 136,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1554.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1361,
#    'bbox': [181.0, 426.0, 102.0, 31.0],
#    'image_id': 137,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3162.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1371,
#    'bbox': [576.0, 540.0, 75.0, 17.0],
#    'image_id': 138,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1275.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1381,
#    'bbox': [798.0, 621.0, 106.0, 31.0],
#    'image_id': 139,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3286.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1391,
#    'bbox': [175.0, 538.0, 239.0, 76.0],
#    'image_id': 140,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 18164.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1401,
#    'bbox': [461.0, 475.0, 244.0, 46.0],
#    'image_id': 141,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 11224.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1411,
#    'bbox': [1064.0, 473.0, 51.0, 52.0],
#    'image_id': 142,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2652.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1421,
#    'bbox': [380.0, 547.0, 128.0, 28.0],
#    'image_id': 143,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3584.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1431,
#    'bbox': [436.0, 510.0, 228.0, 43.0],
#    'image_id': 144,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 9804.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1441,
#    'bbox': [491.0, 331.0, 329.0, 61.0],
#    'image_id': 145,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 20069.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1451,
#    'bbox': [749.0, 487.0, 225.0, 47.0],
#    'image_id': 146,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 10575.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1461,
#    'bbox': [321.0, 552.0, 139.0, 34.0],
#    'image_id': 147,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4726.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1471,
#    'bbox': [539.0, 457.0, 162.0, 32.0],
#    'image_id': 148,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5184.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1481,
#    'bbox': [417.0, 553.0, 161.0, 41.0],
#    'image_id': 149,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6601.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1491,
#    'bbox': [883.0, 433.0, 131.0, 78.0],
#    'image_id': 150,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 10218.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1501,
#    'bbox': [466.0, 513.0, 190.0, 44.0],
#    'image_id': 151,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8360.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1511,
#    'bbox': [913.0, 589.0, 94.0, 28.0],
#    'image_id': 152,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2632.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1521,
#    'bbox': [414.0, 553.0, 92.0, 22.0],
#    'image_id': 153,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2024.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1531,
#    'bbox': [185.0, 515.0, 123.0, 33.0],
#    'image_id': 154,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4059.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1541,
#    'bbox': [481.0, 490.0, 80.0, 112.0],
#    'image_id': 155,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8960.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1551,
#    'bbox': [686.0, 603.0, 83.0, 30.0],
#    'image_id': 156,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2490.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1561,
#    'bbox': [343.0, 534.0, 132.0, 28.0],
#    'image_id': 157,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3696.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1571,
#    'bbox': [775.0, 493.0, 238.0, 101.0],
#    'image_id': 158,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 24038.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1581,
#    'bbox': [471.0, 373.0, 227.0, 41.0],
#    'image_id': 159,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 9307.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1591,
#    'bbox': [463.0, 566.0, 93.0, 20.0],
#    'image_id': 160,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1860.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1601,
#    'bbox': [270.0, 355.0, 182.0, 47.0],
#    'image_id': 161,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8554.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1611,
#    'bbox': [239.0, 528.0, 140.0, 52.0],
#    'image_id': 162,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7280.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1621,
#    'bbox': [918.0, 561.0, 134.0, 39.0],
#    'image_id': 163,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5226.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1631,
#    'bbox': [452.0, 564.0, 81.0, 18.0],
#    'image_id': 164,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1458.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1641,
#    'bbox': [503.0, 557.0, 108.0, 25.0],
#    'image_id': 165,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2700.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1651,
#    'bbox': [212.0, 485.0, 142.0, 66.0],
#    'image_id': 166,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 9372.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1661,
#    'bbox': [193.0, 450.0, 136.0, 28.0],
#    'image_id': 167,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3808.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1671,
#    'bbox': [464.0, 513.0, 262.0, 49.0],
#    'image_id': 168,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 12838.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1681,
#    'bbox': [963.0, 497.0, 88.0, 35.0],
#    'image_id': 169,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3080.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1691,
#    'bbox': [806.0, 511.0, 158.0, 56.0],
#    'image_id': 170,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8848.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1701,
#    'bbox': [230.0, 621.0, 62.0, 22.0],
#    'image_id': 171,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1364.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1711,
#    'bbox': [293.0, 333.0, 231.0, 45.0],
#    'image_id': 172,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 10395.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1721,
#    'bbox': [185.0, 387.0, 165.0, 49.0],
#    'image_id': 173,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8085.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1731,
#    'bbox': [590.0, 383.0, 178.0, 40.0],
#    'image_id': 174,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7120.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1741,
#    'bbox': [304.0, 420.0, 153.0, 41.0],
#    'image_id': 175,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6273.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1751,
#    'bbox': [443.0, 435.0, 180.0, 32.0],
#    'image_id': 176,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5760.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1761,
#    'bbox': [196.0, 382.0, 154.0, 46.0],
#    'image_id': 177,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7084.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1771,
#    'bbox': [394.0, 448.0, 174.0, 38.0],
#    'image_id': 178,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6612.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1781,
#    'bbox': [618.0, 424.0, 136.0, 35.0],
#    'image_id': 179,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4760.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1791,
#    'bbox': [251.0, 618.0, 97.0, 22.0],
#    'image_id': 180,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 2134.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1801,
#    'bbox': [678.0, 531.0, 179.0, 39.0],
#    'image_id': 181,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6981.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1811,
#    'bbox': [377.0, 399.0, 195.0, 38.0],
#    'image_id': 182,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 7410.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1821,
#    'bbox': [626.0, 612.0, 137.0, 32.0],
#    'image_id': 183,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4384.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1831,
#    'bbox': [131.0, 476.0, 222.0, 78.0],
#    'image_id': 184,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 17316.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1841,
#    'bbox': [645.0, 450.0, 147.0, 31.0],
#    'image_id': 185,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 4557.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1851,
#    'bbox': [810.0, 481.0, 183.0, 101.0],
#    'image_id': 186,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 18483.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1861,
#    'bbox': [528.0, 403.0, 200.0, 43.0],
#    'image_id': 187,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8600.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1871,
#    'bbox': [1029.0, 564.0, 96.0, 39.0],
#    'image_id': 188,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3744.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1881,
#    'bbox': [198.0, 573.0, 191.0, 77.0],
#    'image_id': 189,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 14707.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1891,
#    'bbox': [369.0, 393.0, 165.0, 34.0],
#    'image_id': 190,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5610.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1901,
#    'bbox': [496.0, 478.0, 177.0, 48.0],
#    'image_id': 191,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 8496.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1911,
#    'bbox': [397.0, 532.0, 64.0, 19.0],
#    'image_id': 192,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 1216.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1921,
#    'bbox': [175.0, 352.0, 149.0, 41.0],
#    'image_id': 193,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 6109.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1931,
#    'bbox': [889.0, 413.0, 160.0, 37.0],
#    'image_id': 194,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 5920.0,
#    'iscrowd': 0,
#    'category_id': 1},
#   {'id': 1941,
#    'bbox': [1029.0, 497.0, 79.0, 45.0],
#    'image_id': 195,
#    'segmentation': [],
#    'ignore': 0,
#    'area': 3555.0,
#    'iscrowd': 0,
#    'category_id': 1}]}

# %%
coco_dict['images'][-1]
# Out:
# {'file_name': 'Y600YY-93.JPG', 'height': 750, 'width': 1200, 'id': 195}

# %%
coco_dict['annotations'][-1]
# Out:
# {'id': 1941,
#  'bbox': [1029.0, 497.0, 79.0, 45.0],
#  'image_id': 195,
#  'segmentation': [],
#  'ignore': 0,
#  'area': 3555.0,
#  'iscrowd': 0,
#  'category_id': 1}

# %%
with open(os.path.join('data', 'coco_val_autonumber_annotations.json'), "w", encoding="utf-8") as file:
    json.dump(coco_dict, file)

# %%
import cv2
import os 
import random
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
def visualize(image):
    image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    plt.figure(figsize=(40, 20))
    plt.imshow(image)

# %%
visualize(cv2.imread(os.path.join('data', 'train', 'image_0_0.JPG'), cv2.IMREAD_UNCHANGED))
