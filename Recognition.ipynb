# %% [markdown]
# Монтируем google drive

# %%
from google.colab import drive
drive.mount('/content/drive')

drive = 1
if drive==1:
  prefix = '/content/drive/My Drive/Studying/Netology/Diploma'
else:
  prefix = ''
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Устанавливаем зависимости

# %%
import sys, os
sys.path.append(os.path.join(prefix,'lib'))

# %%
from service_lib import install_dependences
install_dependences()
# Out:
# All dependences are installed! You need to restart the environment!

# %% [markdown]
# Импортируем необходимые библиотеки

# %%
import torch, torchvision
import os
import cv2
print(torch.__version__, torch.cuda.is_available(), torchvision.__version__)

from detectron2.data.datasets import register_coco_instances
from detectron2.data import MetadataCatalog, DatasetCatalog

from detectron2.engine import DefaultPredictor
from detectron2.config import get_cfg

from config_lib import make_config_detector, make_config_symbols
from visual_lib import visualize_with_rect, visualize
from prediction import ImagePrediction

import glob
import math
import re

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt



from tqdm.notebook import tqdm

# %matplotlib inline
# Out:
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
#
# ** fvcore version of PathManager will be deprecated soon. **
# ** Please migrate to the version in iopath repo. **
# https://github.com/facebookresearch/iopath
# 1.7.0+cu101 True 0.8.1+cu101

# %% [markdown]
# Рисуем предсказания для тестовых картинок

# %%
cfg = make_config_detector(get_cfg(), prefix)

# %%
carplate_predictor = DefaultPredictor(cfg)

# %%
test_photos = glob.glob(os.path.join(prefix,'data', 'test','*.*'))

# %%
for img in tqdm(test_photos):
  ImgPred = ImagePrediction(img, predictor=carplate_predictor)
  plt.figure(figsize=(20, 50))
  plt.imshow(ImgPred.visualize_prediction())
# Out:
# Output hidden; open in https://colab.research.google.com to view.
